# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.3 MB 14.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.3 MB 19.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 19.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ----- ---------------------------------- 5.2/37.3 MB 26.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.0/37.3 MB 23.3 MB/s eta 0:00:02
#    --------------- ------------------------ 14.7/37.3 MB 23.0 MB/s eta 0:00:01
#    -------------------- ------------------- 19.1/37.3 MB 22.3 MB/s eta 0:00:01
#    ------------------------- -------------- 23.9/37.3 MB 22.2 MB/s eta 0:00:01
#    ------------------------------- -------- 29.6/37.3 MB 23.2 MB/s eta 0:00:01
#    ------------------------------------ --- 33.8/37.3 MB 22.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, auc

# 1. CSV 파일 로드
df = pd.read_csv('G:/내 드라이브/paper/가족효과성/20240430/Family_ML_Analysis_v4_20240201.csv')  # 파일명을 본인의 CSV 파일명으로 변경하세요

# 2. X(특성)와 y(타겟) 분할
# 'target' 컬럼명을 실제 데이터셋의 타겟 컬럼명으로 변경하세요.
X = df.drop(columns=['target'])
y = df['target']

# 3. 학습/테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 4. 비교할 모델 정의
models = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(random_state=42),
    'Naive Bayes': GaussianNB(),
    'SVM (Linear)': SVC(kernel='linear', probability=True, random_state=42),
    'SVM (RBF)': SVC(kernel='rbf', probability=True, random_state=42),
    'SVM (Poly)': SVC(kernel='poly', probability=True, random_state=42),
    'SVM (Sigmoid)': SVC(kernel='sigmoid', probability=True, random_state=42)
}

# 5. ROC 커브 플롯
plt.figure(figsize=(9, 7))

for name, model in models.items():
    model.fit(X_train, y_train)
    
    # 예측 확률 추출
    y_score = model.predict_proba(X_test)[:, 1]
    
    # FPR, TPR 및 AUC 계산
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    
    plt.plot(fpr, tpr, lw=2, label=f'{name} (AUC = {roc_auc:.3f})')

# 6. 그래프 스타일 설정
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Random Guessing (AUC = 0.500)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - Specificity)', fontsize=12)
plt.ylabel('True Positive Rate (Sensitivity)', fontsize=12)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=14, fontweight='bold')
plt.legend(loc="lower right", fontsize=10)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('roc_curve_from_dataset.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 15
#      11 df = pd.read_csv('G:/내 드라이브/paper/가족효과성/20240430/Family_ML_Analysis_v4_20240201.csv')  # 파일명을 본인의 CSV 파일명으로 변경하세요
#      12
#      13 # 2. X(특성)와 y(타겟) 분할
#      14 # 'target' 컬럼명을 실제 데이터셋의 타겟 컬럼명으로 변경하세요.
# ---> 15 X = df.drop(columns=['target'])
#      16 y = df['target']
#      17
#      18 # 3. 학습/테스트 데이터 분할
#
# File c:\workspace\python\playground_env\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6142 def drop(
#    6143     self,
#    6144     labels: IndexLabel | ListLike = None,
#    (...)   6151     errors: IgnoreRaise = "raise",
#    6152 ) -> DataFrame | None:
#    6153     """
#    6154     Drop specified labels from rows or columns.
#    6155
#    (...)   6298             weight  1.0     0.8
# ...
