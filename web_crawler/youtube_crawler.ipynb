# %%
import youtube_crawler
import importlib
importlib.reload(youtube_crawler)
MY_API_KEY = "AIzaSyAxDTxXuVQ4hZBBBOqnR_EbTjItOKSTMBc" 
MY_API_KEY = 'AIzaSyDWObDSPy2JuMkJuYHIO_Un1Qutm8QMoXg'
KEYWORD = ["마른김", "김산업"] 
#KEYWORD = ["아이폰 15", "갤럭시 S24"] # OR 검색 예시
for year in ['2023','2025']:
    # 함수 실행
    youtube_crawler.main(
            api_key=MY_API_KEY,
            search_keyword=KEYWORD,
            max_videos=1000,
            max_comments_per_video=1000,
            search_start_date=f"{year}-01-01", # 예: "2023-01-01"
            search_end_date=f"{year}-12-31",
            collect_script=True,
            output_filename=None, # 예: "my_result.csv"
            output_folder=f"./result/{year}", # 예: "./result" (저장할 폴더 지정)
            stopwords_file='stopwords.txt'
    )
# Out:
# [2026-01-13 07:42:48] [INFO] [Line 103] 불용어 파일 로드 완료: 596개 단어
# [2026-01-13 07:42:48] [INFO] [Line 725] 폴더 생성: ./result/2023
# [2026-01-13 07:42:48] [INFO] [Line 49] file_cache is only supported with oauth2client<4.0.0
# [2026-01-13 07:42:48] [INFO] [Line 776] ['마른김, 김산업'] 키워드로 영상을 검색합니다...
# [2026-01-13 07:42:48] [INFO] [Line 132] 검색 시작일 설정: 2023-01-01
# [2026-01-13 07:42:48] [INFO] [Line 134] 검색 종료일 설정: 2023-12-31
# [2026-01-13 07:42:55] [INFO] [Line 785] 총 310개의 영상을 찾았습니다. 수집을 시작합니다.
# [2026-01-13 07:42:55] [INFO] [Line 788] 1. [Harry ko (harry ko)] 한국마른김 생산과정중 건조과정 전단계... (조회수: 209)
# [2026-01-13 07:42:55] [INFO] [Line 788] 2. [김학래 임미숙의 웃짜 채날] 초간단 곱창김 굽기! 미숙언니가 알려드려요~... (조회수: 512219)
# [2026-01-13 07:42:55] [INFO] [Line 788] 3. [알콩할미네 집밥] 💥냉동실에 있는 마른 김 전자렌인지에 넣어 보세요! 너무 편하고 순식간에... (조회수: 38811)
# [2026-01-13 07:42:55] [INFO] [Line 788] 4. [요리하는 장보고 Jangbogo] 오래된 묵은김 다 꺼내오세요! 이게 진정 밥도둑입니다~ 김 장아찌 황금레... (조회수: 130775)
# ...

# %%
# !sudo apt-get install -y fonts-nanum
